# %%
import pandas as pd

# %%
# %cd "/mas/projects/prg-candor/"
# %ls
# Out:
# /mas/projects/prg-candor
# processed_media_part_001/  processed_media_part_013/  processed_media_part_025/
# processed_media_part_002/  processed_media_part_014/  processed_media_part_026/
# processed_media_part_003/  processed_media_part_015/  processed_media_part_027/
# processed_media_part_004/  processed_media_part_016/  processed_media_part_028/
# processed_media_part_005/  processed_media_part_017/  processed_media_part_029/
# processed_media_part_006/  processed_media_part_018/  processed_media_part_030/
# processed_media_part_007/  processed_media_part_019/  processed_media_part_031/
# processed_media_part_008/  processed_media_part_020/  processed_media_part_032/
# processed_media_part_009/  processed_media_part_021/  processed_media_part_033/
# processed_media_part_010/  processed_media_part_022/  processed_media_part_034/
# processed_media_part_011/  processed_media_part_023/
# processed_media_part_012/  processed_media_part_024/

# %%
import os
import shutil

target_dir = "/u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/"
for root, dirs, files in os.walk("./"):
    for file in files:
        if "audio_video_features.csv" in file:
            source_path = os.path.join(root, file)
            target_filename = target_dir + root.split("/")[-1]
            print(target_filename)
            target_path = os.path.join(root, target_filename + ".csv")
            shutil.copy(source_path, target_path)
# Out:
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/7595d874-c1cb-4aef-918f-3c81f3a84324
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/66768810-879d-4e2f-b5f5-ecc67d298104
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/dc3d0ae4-8d20-4d1d-8e0c-82c85a79b26e
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/fb50ccf7-1a5a-4d80-b4f0-d5d1a1fd1135
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/73c201ef-8c32-43d4-b642-dcedf4aa5c7f
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/42ce8122-bc6c-4c25-8e90-0cb2f2406432
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/7cda8619-2b2d-4344-901e-2e6de0a6101a
# /u/sebono/conversational_dominance/data/processed/CANDOR/affective_labels/911bdf35-886c-451d-a26e-7b841cb17806
# ...
